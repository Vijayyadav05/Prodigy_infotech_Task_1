# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from warnings import filterwarnings
filterwarnings('ignore')
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv(r"C:\Users\vijay yadav\Downloads\Task_1_Data\Total Pop.csv")
df.head()
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54608.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8622466.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5357195.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL     9443.0
#
#         1961       1962       1963       1964       1965  ...        2014  \
# 0    55811.0    56682.0    57475.0    58178.0    58782.0  ...    103594.0
# 1  8790140.0  8969047.0  9157465.0  9355514.0  9565147.0  ...  32716210.0
# 2  5441333.0  5521400.0  5599827.0  5673199.0  5736582.0  ...  27128337.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0  ...   2889104.0
# 4    10216.0    11014.0    11839.0    12690.0    13563.0  ...     71621.0
#
#          2015        2016        2017        2018        2019        2020  \
# ...

# %%
df.shape
# Out:
# (1090, 68)

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1090 entries, 0 to 1089
# Data columns (total 68 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    1090 non-null   object
#  1   Country Code    1090 non-null   object
#  2   Indicator Name  1090 non-null   object
#  3   Indicator Code  1090 non-null   object
#  4   1960            1082 non-null   float64
#  5   1961            1082 non-null   float64
#  6   1962            1082 non-null   float64
#  7   1963            1082 non-null   float64
#  8   1964            1082 non-null   float64
#  9   1965            1082 non-null   float64
#  10  1966            1082 non-null   float64
#  11  1967            1082 non-null   float64
#  12  1968            1082 non-null   float64
#  13  1969            1082 non-null   float64
#  14  1970            1082 non-null   float64
#  15  1971            1082 non-null   float64
#  16  1972            1082 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              8
# 1961              8
# 1962              8
# 1963              8
# 1964              8
# 1965              8
# 1966              8
# 1967              8
# 1968              8
# 1969              8
# 1970              8
# 1971              8
# 1972              8
# 1973              8
# 1974              8
# 1975              8
# 1976              8
# 1977              8
# 1978              8
# 1979              8
# 1980              8
# 1981              8
# 1982              8
# 1983              8
# 1984              8
# 1985              8
# 1986              8
# 1987              8
# 1988              8
# 1989              8
# 1990              5
# 1991              5
# 1992              5
# 1993              5
# 1994              5
# 1995              5
# 1996              5
# 1997              5
# 1998              5
# 1999              5
# 2000              5
# ...

# %%
# Display rows where at least one column has a null value
df_null = df[df.isnull().any(axis=1)]
print(df_null)
# Out:
#            Country Name Country Code  \
# 90       Not classified          INX
# 162  West Bank and Gaza          PSE
# 308      Not classified          INX
# 380  West Bank and Gaza          PSE
# 526      Not classified          INX
# 598  West Bank and Gaza          PSE
# 744      Not classified          INX
# 962      Not classified          INX
#
#                                  Indicator Name     Indicator Code  1960  \
# 90                            Population, total        SP.POP.TOTL   NaN
# 162                           Population, total        SP.POP.TOTL   NaN
# 308                            Population, male  SP.POP.TOTL.MA.IN   NaN
# 380                            Population, male  SP.POP.TOTL.MA.IN   NaN
# 526                          Population, female  SP.POP.TOTL.FE.IN   NaN
# 598                          Population, female  SP.POP.TOTL.FE.IN   NaN
# 744    Population, male (% of total population)  SP.POP.TOTL.MA.ZS   NaN
# ...

# %%
# checking for duplicates
df[df.duplicated]
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, Indicator Code, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
# Index: []
#
# [0 rows x 68 columns]

# %%
# checking for how many percent we have null values
null_perc = (df.isnull().sum())/(df.shape[0])*100
null_perc
# Out:
# Country Name      0.000000
# Country Code      0.000000
# Indicator Name    0.000000
# Indicator Code    0.000000
# 1960              0.733945
# 1961              0.733945
# 1962              0.733945
# 1963              0.733945
# 1964              0.733945
# 1965              0.733945
# 1966              0.733945
# 1967              0.733945
# 1968              0.733945
# 1969              0.733945
# 1970              0.733945
# 1971              0.733945
# 1972              0.733945
# 1973              0.733945
# 1974              0.733945
# 1975              0.733945
# 1976              0.733945
# 1977              0.733945
# 1978              0.733945
# 1979              0.733945
# 1980              0.733945
# 1981              0.733945
# 1982              0.733945
# 1983              0.733945
# 1984              0.733945
# 1985              0.733945
# 1986              0.733945
# 1987              0.733945
# 1988              0.733945
# 1989              0.733945
# ...

# %%
# We have less than 1% null value and also no information we have, so we drop the null values.
dropinig =df.dropna(inplace=True)

# %%
df.shape
# Out:
# (1082, 68)

# %%
df
# Out:
#                         Country Name Country Code  \
# 0                              Aruba          ABW
# 1                        Afghanistan          AFG
# 2                             Angola          AGO
# 3                            Albania          ALB
# 4                            Andorra          AND
# 5               United Arab Emirates          ARE
# 6                          Argentina          ARG
# 7                            Armenia          ARM
# 8                     American Samoa          ASM
# 9                Antigua and Barbuda          ATG
# 10                         Australia          AUS
# 11                           Austria          AUT
# 12                        Azerbaijan          AZE
# 13                           Burundi          BDI
# 14                           Belgium          BEL
# 15                             Benin          BEN
# 16                      Burkina Faso          BFA
# 17                        Bangladesh          BGD
# ...

# %%
# Filter data for total population
total_population_data_20 = df[df['Indicator Code'] == 'SP.POP.TOTL']

# Sort data based on the total population for 2023
total_population_sorted = total_population_data_20.sort_values(by="2023", ascending=False)

# Get the top ten countries with the highest total population for 2023
total_top_ten_countries_2023 = total_population_sorted.head(10)
print("Top ten countries of total population\n")
print(total_top_ten_countries_2023[['Country Name']])
# Out:
# Top ten countries of total population
#
#            Country Name
# 89                India
# 36                China
# 204       United States
# 87            Indonesia
# 151            Pakistan
# 143             Nigeria
# 26               Brazil
# 17           Bangladesh
# 166  Russian Federation
# 126              Mexico

# %%
# Filter data for total population
total_population_data_19 = df[df['Indicator Code'] == 'SP.POP.TOTL']

# Sort data based on the total population for 2023
total_population_sorted = total_population_data_19.sort_values(by="1960", ascending=False)

# Get the top ten countries with the highest total population for 1960
total_top_ten_countries_1960 = total_population_sorted.head(10)
print("Top ten countries of total population\n")
print(total_top_ten_countries_1960[['Country Name']])
# Out:
# Top ten countries of total population
#
#            Country Name
# 36                China
# 89                India
# 204       United States
# 166  Russian Federation
# 99                Japan
# 87            Indonesia
# 26               Brazil
# 50              Germany
# 68       United Kingdom
# 17           Bangladesh

# %% [markdown]
# ## Top ten countries of the total population difference from 1990 to 2023

# %%
# Create the bar plot
plt.figure(figsize=(15, 6))
plt.subplot(2,2,1)
sns.barplot(x="2023", y="Country Name", data=total_top_ten_countries_2023, palette="cool")
plt.title("Top Ten Countries of Total Population (2023)",fontsize=10)
plt.xlabel("Total Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()

# Create the bar plot
plt.figure(figsize=(15, 6))
plt.subplot(2,2,2)
sns.barplot(x="1960", y="Country Name", data=total_top_ten_countries_1960, palette="cool")
plt.title("Top Ten Countries of Total Population (1960)",fontsize=10)
plt.xlabel("Total Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()

# %% [markdown]
# ## Extraction of bottom 10 countries with respect to total popultaion

# %%
# Sort data based on the total population for 2022
total_population_sorted1 = total_population_data_19.sort_values(by="2023", ascending=True)

# Get the top ten countries with the highest total population for 2022
total_bottom_ten_countries_2023 = total_population_sorted1.head(10)
print("Bottom ten countries of total population\n")
print(total_bottom_ten_countries_2023[['Country Code']])
# Out:
# Bottom ten countries of total population
#
#     Country Code
# 199          TUV
# 148          NRU
# 155          PLW
# 208          VGB
# 120          MAF
# 71           GIB
# 175          SMR
# 122          MCO
# 113          LIE
# 127          MHL

# %%
# Sort data based on the total population for 2023
total_population_sorted1 = total_population_data_20.sort_values(by="1960", ascending=True)

# Get the top ten countries with the highest total population for 2022
total_bottom_ten_countries_1960 = total_population_sorted1.head(10)
print("Bottom ten countries of total population\n")
print(total_bottom_ten_countries_1960[['Country Code']])
# Out:
# Bottom ten countries of total population
#
#     Country Code
# 120          MAF
# 148          NRU
# 199          TUV
# 188          TCA
# 208          VGB
# 47           CYM
# 134          MNP
# 4            AND
# 155          PLW
# 127          MHL

# %%
# Create the bar plot
plt.figure(figsize=(15, 6))
plt.subplot(2,2,1)
sns.barplot(x="2023", y="Country Name", data=total_bottom_ten_countries_2023, palette="cool")
plt.title("Bottom Ten Countries of Total Population (2023)",fontsize=10)
plt.xlabel("Total Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()

# Create the bar plot
plt.figure(figsize=(15, 6))
plt.subplot(2,2,2)
sns.barplot(x="1960", y="Country Name", data=total_bottom_ten_countries_1960, palette="cool")
plt.title("Bottom Ten Countries of Total Population (1960)",fontsize=10)
plt.xlabel("Total Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()

# %% [markdown]
# ## Extarction of top 10 countries with highest male population

# %%
#filter data for male population
male_population_data = df[df['Indicator Code']=='SP.POP.TOTL.MA.IN']

#sort data based on the male population for 2022
male_population_sorted =male_population_data.sort_values(by="2023",ascending=False)

#Get the top 10 countries with the highest male population for 2022
male_top_ten_countries = male_population_sorted .head(10)
print("Top ten countries of male population")
print(male_top_ten_countries[['Country Code']])
# Out:
# Top ten countries of male population
#     Country Code
# 307          IND
# 254          CHN
# 422          USA
# 305          IDN
# 369          PAK
# 361          NGA
# 244          BRA
# 235          BGD
# 384          RUS
# 279          ETH

# %%
# Create the bar plot
plt.figure(figsize=(15, 6))
plt.subplot(2,2,1)
sns.barplot(x="2023", y="Country Name", data=male_top_ten_countries, palette="cool")
plt.title("Top ten conuntries of male population(2023)",fontsize=10)
plt.xlabel("Male Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()

plt.figure(figsize=(15, 6))
plt.subplot(2,2,1)
sns.barplot(x="1960", y="Country Name", data=male_top_ten_countries, palette="cool")
plt.title("Top ten conuntries of male population(1960)",fontsize=10)
plt.xlabel("Male Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()

# %%
#filter data for male population
female_population_data = df[df['Indicator Code']=='SP.POP.TOTL.FE.IN']

#sort data based on the male population for 2023
female_population_sorted =female_population_data.sort_values(by="2023",ascending=False)

#Get the top 10 countries with the highest male population for 2022
female_top_ten_countries = female_population_sorted .head(10)
print("Top ten countries of female population")
print(female_top_ten_countries[['Country Code']])
# Out:
# Top ten countries of female population
#     Country Code
# 525          IND
# 472          CHN
# 640          USA
# 523          IDN
# 587          PAK
# 579          NGA
# 462          BRA
# 453          BGD
# 602          RUS
# 562          MEX

# %%
# Create the bar plot
plt.figure(figsize=(15, 6))
plt.subplot(2,2,2)
sns.barplot(x="2023", y="Country Name", data=female_top_ten_countries, palette="cool")
plt.title("Top ten conuntries of female population(2023)",fontsize=10)
plt.xlabel("Female Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()

plt.figure(figsize=(15, 6))
plt.subplot(2,2,2)
sns.barplot(x="1960", y="Country Name", data=female_top_ten_countries, palette="cool")
plt.title("Top ten conuntries of female population(1960)",fontsize=10)
plt.xlabel("Female Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()

# %% [markdown]
# ## Top 10 countries with male and female population

# %%
#merge male and female population data on 'Country Code'
merge_data=pd.merge(male_population_data,female_population_data,on="Country Name",suffixes=("_male","_female"))

# %%
#merged data
#calculate the total population for each country (male + female)
merge_data["Total population"] = merge_data["2023_male"] + merge_data ["2023_female"]
merge_data["Total population"]
# Out:
# 0      1.062770e+05
# 1      4.223985e+07
# 2      3.668420e+07
# 3      2.745972e+06
# 4      8.008800e+04
# 5      9.516872e+06
# 6      4.665458e+07
# 7      2.777971e+06
# 8      4.391500e+04
# 9      9.429700e+04
# 10     2.663854e+07
# 11     9.132384e+06
# 12     1.011256e+07
# 13     1.323856e+07
# 14     1.182259e+07
# 15     1.371283e+07
# 16     2.325148e+07
# 17     1.729543e+08
# 18     6.430370e+06
# 19     1.485509e+06
# 20     4.126240e+05
# 21     3.210847e+06
# 22     9.178298e+06
# 23     4.108250e+05
# 24     6.348900e+04
# 25     1.238857e+07
# 26     2.164224e+08
# 27     2.819950e+05
# 28     4.525230e+05
# 29     7.874240e+05
# 30     2.675352e+06
# 31     5.742315e+06
# 32     4.009776e+07
# 33     8.849852e+06
# 34     1.753460e+05
# 35     1.962959e+07
# 36     1.410710e+09
# 37     2.887303e+07
# 38     2.864729e+07
# 39     1.022628e+08
# 40     6.106869e+06
# 41     5.208517e+07
# 42     8.520750e+05
# 43     5.986820e+05
# 44     5.212174e+06
# ...

# %%
#sort data based on total population in descending order
sorted_data = merge_data.sort_values(by="Total population", ascending=False)
top_10_countries = sorted_data.head(10)

# %%
#create the staked bar plot
plt.figure(figsize=(12,6))
sns.barplot(x="Country Name",y="2023_female",data=top_10_countries,color="red",label="female Population")
sns.barplot(x="Country Name",y="2023_male",data=top_10_countries,bottom=top_10_countries["2023_female"],color="orange",label="Male Population")
plt.xlabel("Country")
plt.ylabel("Population")
plt.legend()
plt.xticks(rotation=45,ha="right")
plt.show()

# %% [markdown]
# ## Bottom 10 countries with male and female population(2023)

# %%
#select the top 10 countries with the highest total population
bottom_10_countries = sorted_data.tail(10)

# %%
# Create the stacked bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x="Country Name", y="2023_female", data=bottom_10_countries, color="red", label="Female Population")
sns.barplot(x="Country Name", y="2023_male", data=bottom_10_countries, bottom=bottom_10_countries["2023_female"], color="orange", label="Male Population")
plt.xlabel("Country")
plt.ylabel("Population")
plt.legend()
plt.xticks(rotation=45, ha="right")
plt.show()
